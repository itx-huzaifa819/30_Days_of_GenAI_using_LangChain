# %% [markdown]
# <a href="https://colab.research.google.com/github/itx-huzaifa819/30_Days_of_GenAI_using_LangChain/blob/main/langchain_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

class SimpleLLM:

  def __init__(self):
    print('LLM created')

  def predict(self, prompt):

    response_list = [
        'Islamabad is the capital of Pakistan',
        'PSL is a cricket league',
        'GPT stands for Generative Pre-trained Transformer'
    ]

    return {'response': random.choice(response_list)}

# %%
class SimplePromptTemplate:

  def __init__(self, template, input_variables):
    self.template = template
    self.input_variables = input_variables

  def format(self, input_dict):
    return self.template.format(**input_dict)

# %%
template = SimplePromptTemplate(
    template='Write a {length} poem about {topic}',
    input_variables=['length', 'topic']
)

# %%
prompt = template.format({'length':'short','topic':'Pakistan'})

# %%
llm = SimpleLLM()
# Out:
# LLM created

# %%
llm.predict(prompt)
# Out:
# {'response': 'PSL is a cricket league'}

# %%
class SimpleLLMChain:

  def __init__(self, llm, prompt):
    self.llm = llm
    self.prompt = prompt

  def run(self, input_dict):

    final_prompt = self.prompt.format(input_dict)
    result = self.llm.predict(final_prompt)

    return result['response']

# %%
template = SimplePromptTemplate(
    template='Write a {length} poem about {topic}',
    input_variables=['length', 'topic']
)

# %%
llm = SimpleLLM()
# Out:
# LLM created

# %%
chain = SimpleLLMChain(llm, template)

# %%
chain.run({'length':'short', 'topic': 'Pakistan'})
# Out:
# 'PSL is a cricket league'
